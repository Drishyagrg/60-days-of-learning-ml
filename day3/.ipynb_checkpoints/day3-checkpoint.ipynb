# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('anime_dataset.csv')

# %%
df.head()
# Out:
#    mal_id                            title            title_english  \
# 0       1                     Cowboy Bebop             Cowboy Bebop
# 1       5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2       6                           Trigun                   Trigun
# 3       7               Witch Hunter Robin       Witch Hunter Robin
# 4       8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                      title_japanese   type    source  episodes  \
# 0                         カウボーイビバップ     TV  Original      26.0
# 1                    カウボーイビバップ 天国の扉  Movie  Original       1.0
# 2                             トライガン     TV     Manga      26.0
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)     TV  Original      26.0
# 4                            冒険王ビィト     TV     Manga      52.0
#
#             status  airing  aired_from  ...  season    year         studios  \
# 0  Finished Airing   False  1998-04-03  ...  spring  1998.0         Sunrise
# ...

# %%
df.columns
# Out:
# Index(['mal_id', 'title', 'title_english', 'title_japanese', 'type', 'source',
#        'episodes', 'status', 'airing', 'aired_from', 'aired_to', 'duration',
#        'rating', 'score', 'scored_by', 'rank', 'popularity', 'members',
#        'favorites', 'season', 'year', 'studios', 'producers', 'licensors',
#        'genres', 'themes', 'demographics', 'synopsis', 'image_url'],
#       dtype='object')

# %%
df= df[['mal_id','title','title_english','type','episodes','status','airing','duration','rating','rank','season','genres','studios','year','themes']]

# %% [markdown]
# # new dataset with less columns

# %%
df.to_csv('anime_datasets.csv')

# %%
df= pd.read_csv('anime_datasets.csv')

# %%
df= df.iloc[:,1:]

# %%
df
# Out:
#        mal_id                            title            title_english  \
# 0           1                     Cowboy Bebop             Cowboy Bebop
# 1           5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2           6                           Trigun                   Trigun
# 3           7               Witch Hunter Robin       Witch Hunter Robin
# 4           8                   Bouken Ou Beet   Beet the Vandel Buster
# ...       ...                              ...                      ...
# 30070   64004                     Manzoku desu                      NaN
# 30071   64005                          Overlay                      NaN
# 30072   64006     Megane, Tokidoki, Yankee-kun                      NaN
# 30073   64012                  The Ribbon Hero          The Ribbon Hero
# 30074   64012                  The Ribbon Hero          The Ribbon Hero
#
#         type  episodes           status  airing       duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30075 entries, 0 to 30074
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mal_id         30075 non-null  int64
#  1   title          30075 non-null  object
#  2   title_english  13306 non-null  object
#  3   type           30003 non-null  object
#  4   episodes       29236 non-null  float64
#  5   status         30075 non-null  object
#  6   airing         30075 non-null  bool
#  7   duration       30075 non-null  object
#  8   rating         29473 non-null  object
#  9   rank           22584 non-null  float64
#  10  season         6525 non-null   object
#  11  genres         23681 non-null  object
#  12  studios        18137 non-null  object
#  13  year           6525 non-null   float64
#  14  themes         17977 non-null  object
# dtypes: bool(1), float64(3), int64(1), object(10)
# memory usage: 3.2+ MB

# %%
df.isnull().sum()
# Out:
# mal_id               0
# title                0
# title_english    16769
# type                72
# episodes           839
# status               0
# airing               0
# duration             0
# rating             602
# rank              7491
# season           23550
# genres            6394
# studios          11938
# year             23550
# themes           12098
# dtype: int64

# %%
df.describe()
# Out:
#              mal_id      episodes          rank         year
# count  30075.000000  29236.000000  22584.000000  6525.000000
# mean   35019.558537     13.958886  11275.337894  2010.646130
# std    19983.466507     47.334180   6508.725236    13.294049
# min        1.000000      1.000000      1.000000  1961.000000
# 25%    16833.000000      1.000000   5636.750000  2005.000000
# 50%    38852.000000      2.000000  11275.000000  2014.000000
# 75%    52131.500000     13.000000  16909.250000  2021.000000
# max    64012.000000   3000.000000  22548.000000  2027.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(139)

# %% [markdown]
# # EDA using Univariate Analysis

# %% [markdown]
# ## Categorical Data

# %%
sns.countplot(df['type'])
# Out:
# <Axes: xlabel='count', ylabel='type'>

# %%
sns.countplot(df['status'])
# Out:
# <Axes: xlabel='count', ylabel='status'>

# %%
sns.countplot(df['genres'])
# Out:
# <Axes: xlabel='count', ylabel='genres'>

# %%
df['type'].value_counts().plot(kind='pie', autopct= "%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Numerical Data

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['year'], bins=7)
# Out:
# (array([  96.,  191.,  314.,  379., 1224., 1957., 2364.]),
#  array([1961.        , 1970.42857143, 1979.85714286, 1989.28571429,
#         1998.71428571, 2008.14285714, 2017.57142857, 2027.        ]),
#  <BarContainer object of 7 artists>)

# %%
sns.distplot(df['year'])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_11708\1705408248.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['year'])
# <Axes: xlabel='year', ylabel='Density'>

# %%
sns.boxplot(df['duration'])
# Out:
# <Axes: ylabel='duration'>
