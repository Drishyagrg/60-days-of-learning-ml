# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install ydata_profiling
# Out:
# Collecting ydata_profiling
#   Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (2.10.3)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata_profiling)
#   Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (2.1.3)
# Collecting minify-html>=0.15.0 (from ydata_profiling)
#   Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata_profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata_profiling)
#   Downloading phik-0.12.5-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.66.3 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata_profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (0.14.4)
# Collecting typeguard<5,>=4 (from ydata_profiling)
#   Downloading typeguard-4.5.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.2 (from ydata_profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata_profiling)
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata_profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in C:\Users\ACER\anaconda3\Lib\site-packages (from ydata_profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in C:\Users\ACER\anaconda3\Lib\site-packages (from imagehash==4.3.2->ydata_profiling) (1.8.0)
# Requirement already satisfied: pillow in C:\Users\ACER\anaconda3\Lib\site-packages (from imagehash==4.3.2->ydata_profiling) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\ACER\anaconda3\Lib\site-packages (from jinja2<3.2,>=3.1.6->ydata_profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\ACER\anaconda3\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata_profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in C:\Users\ACER\anaconda3\Lib\site-packages (from numba<0.63,>=0.60->ydata_profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\ACER\anaconda3\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata_profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from phik<0.13,>=0.12.5->ydata_profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\ACER\anaconda3\Lib\site-packages (from pydantic<3,>=2->ydata_profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from pydantic<3,>=2->ydata_profiling) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in C:\Users\ACER\anaconda3\Lib\site-packages (from pydantic<3,>=2->ydata_profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\ACER\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\ACER\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\ACER\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\ACER\anaconda3\Lib\site-packages (from requests<3,>=2.32.0->ydata_profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\ACER\anaconda3\Lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (1.0.1)
# Requirement already satisfied: colorama in C:\Users\ACER\anaconda3\Lib\site-packages (from tqdm<5,>=4.66.3->ydata_profiling) (0.4.6)
# Collecting typing-extensions>=4.12.2 (from pydantic<3,>=2->ydata_profiling)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=19.3.0 in C:\Users\ACER\anaconda3\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (24.3.0)
# Requirement already satisfied: networkx>=2.4 in C:\Users\ACER\anaconda3\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata_profiling)
#   Downloading puremagic-2.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\ACER\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata_profiling) (1.17.0)
# Downloading ydata_profiling-4.18.4-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp313-cp313-win_amd64.whl (678 kB)
#    ---------------------------------------- 0.0/678.1 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/678.1 kB ? eta -:--:--
#    ---------------------------------------- 678.1/678.1 kB 2.3 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading typeguard-4.5.2-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp313-cp313-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/3.1 MB 2.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.3/3.1 MB 2.1 MB/s eta 0:00:01
#    -------------------- ------------------- 1.6/3.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.1 MB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 2.4/3.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.9/3.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 1.9 MB/s  0:00:01
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Downloading puremagic-2.2.0-py3-none-any.whl (71 kB)
# Installing collected packages: minify-html, filetype, typing-extensions, PyYAML, puremagic, multimethod, dacite, typeguard, imagehash, wordcloud, visions, phik, ydata_profiling
#
#    ----------------------------------------  0/13 [minify-html]
#    --- ------------------------------------  1/13 [filetype]
#   Attempting uninstall: typing-extensions
#    --- ------------------------------------  1/13 [filetype]
#     Found existing installation: typing_extensions 4.12.2
#    --- ------------------------------------  1/13 [filetype]
#     Uninstalling typing_extensions-4.12.2:
#    --- ------------------------------------  1/13 [filetype]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#       Successfully uninstalled typing_extensions-4.12.2
#    ------ ---------------------------------  2/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [typing-extensions]
#   Attempting uninstall: PyYAML
#    ------ ---------------------------------  2/13 [typing-extensions]
#    --------- ------------------------------  3/13 [PyYAML]
#     Found existing installation: PyYAML 6.0.2
#    --------- ------------------------------  3/13 [PyYAML]
#     Uninstalling PyYAML-6.0.2:
#    --------- ------------------------------  3/13 [PyYAML]
#       Successfully uninstalled PyYAML-6.0.2
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    --------- ------------------------------  3/13 [PyYAML]
#    ------------ ---------------------------  4/13 [puremagic]
#    ------------------ ---------------------  6/13 [dacite]
#    ------------------------ ---------------  8/13 [imagehash]
#    --------------------------- ------------  9/13 [wordcloud]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    --------------------------------- ------ 11/13 [phik]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ------------------------------------ --- 12/13 [ydata_profiling]
#    ---------------------------------------- 13/13 [ydata_profiling]
#
# Successfully installed PyYAML-6.0.3 dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-2.2.0 typeguard-4.5.2 typing-extensions-4.15.0 visions-0.8.1 wordcloud-1.9.6 ydata_profiling-4.18.4
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ACER\anaconda3\Lib\site-packages\~aml'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport

df = pd.read_csv('train_data.csv')
profile = ProfileReport(df, title="Profiling Report")
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_14932\887489743.py:1: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
profile.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                           | 0/17 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 127.35it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df=pd.read_csv("train_data.csv")

# %%
df.sample(5)
# Out:
#      Unnamed: 0  PassengerId  Survived  Sex     Age      Fare  Pclass_1  \
# 38           38           39         0    0  0.2250  0.035134         0
# 472         472          473         1    0  0.4125  0.054164         0
# 370         370          371         1    1  0.3125  0.108215         1
# 539         539          540         1    0  0.2750  0.096618         1
# 388         388          389         0    1  0.3500  0.015086         0
#
#      Pclass_2  Pclass_3  Family_size  Title_1  Title_2  Title_3  Title_4  \
# 38          0         1          0.2        0        0        0        1
# 472         1         0          0.3        1        0        0        0
# 370         0         0          0.1        1        0        0        0
# 539         0         0          0.2        0        0        0        1
# 388         0         1          0.0        1        0        0        0
#
#      Emb_1  Emb_2  Emb_3
# 38       0      0      1
# 472      0      0      1
# 370      1      0      0
# 539      1      0      0
# 388      0      1      0

# %%
df1 = pd.read_csv("Social_Network_Ads.csv")

# %%
df1.sample(5)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 210  15724536  Female   48            96000          1
# 257  15794493    Male   40            57000          0
# 57   15807481    Male   28            79000          0
# 239  15772073  Female   53           143000          1
# 66   15679760    Male   24            19000          0

# %%
df1=df1.iloc[:,2:]

# %%
df1.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(df1.drop('Purchased', axis=1), df1['Purchased'], test_size=0.3, random_state=42)

X_train.shape, X_test.shape
# Out:
# ((280, 2), (120, 2))

# %% [markdown]
# ## StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
scaler.mean_
# Out:
# array([3.75750000e+01, 7.05892857e+04])

# %%
X_train
# Out:
#      Age  EstimatedSalary
# 157   29            75000
# 109   38            80000
# 17    45            26000
# 347   54           108000
# 24    46            23000
# ..   ...              ...
# 71    24            27000
# 106   26            35000
# 270   43           133000
# 348   39            77000
# 102   32            86000
#
# [280 rows x 2 columns]

# %%
X_train_scaled
# Out:
# array([[-0.84252154,  0.1301563 ],
#        [ 0.04175763,  0.2777019 ],
#        [ 0.72953032, -1.31579061],
#        [ 1.61380949,  1.10395728],
#        [ 0.82778356, -1.40431797],
#        [-1.43204099, -1.25677236],
#        [-0.05649561,  0.1301563 ],
#        [ 0.43477059, -0.16493491],
#        [-0.2530021 ,  0.01211982],
#        [ 1.31904976,  2.22530386],
#        [ 0.14001087,  0.74984783],
#        [-1.33378775,  0.54328399],
#        [ 2.00682245,  0.72033871],
#        [-1.23553451, -1.43382709],
#        [ 0.33651735, -0.34198963],
#        [-0.94077478,  0.54328399],
#        [ 0.43477059,  0.2777019 ],
#        [ 0.43477059,  1.10395728],
#        [ 0.82778356,  0.74984783],
#        [ 0.9260368 ,  1.25150288],
#        [-0.44950858, -1.25677236],
#        [-1.82505395, -1.34529973],
#        [ 1.12254328,  0.54328399],
#        [-0.64601506, -1.64039093],
#        [-0.7442683 ,  0.24819278],
#        [ 1.02429004,  2.07775825],
#        [-0.54776182,  1.36953936],
#        [-0.05649561,  0.01211982],
#        [-1.9233072 ,  0.45475663],
#        [ 0.43477059,  0.24819278],
#        [-1.03902802,  0.39573838],
#        [ 0.23826411, -0.16493491],
#        [ 1.90856921,  0.10064718],
#        [-1.13728127, -1.64039093],
#        [-1.13728127,  0.2777019 ],
#        [-0.84252154, -0.81413556],
#        [-0.44950858,  2.31383122],
#        [ 0.14001087, -0.84364468],
#        [ 1.61380949,  0.98592079],
#        [-0.15474885, -1.10922676],
#        [ 0.82778356, -1.13873588],
#        [ 0.23826411,  2.10726737],
#        [-0.05649561, -0.25346227],
#        [-0.84252154,  2.2843221 ],
#        [-0.05649561, -0.40100787],
#        [-0.2530021 , -0.60757171],
#        [ 0.43477059, -0.51904435],
#        [-0.2530021 , -0.96168116],
#        [ 0.33651735, -1.19775412],
#        [ 0.23826411,  0.04162894],
#        [-1.13728127, -1.64039093],
#        [-0.64601506, -0.07640754],
#        [-0.2530021 , -0.51904435],
#        [-0.2530021 , -1.34529973],
#        [-0.7442683 ,  0.54328399],
#        [ 0.33651735,  0.04162894],
#        [-0.94077478,  1.54659408],
#        [ 0.82778356,  0.33672014],
#        [-1.53029423, -0.22395315],
#        [ 0.72953032, -1.43382709],
#        [-0.7442683 , -0.63708083],
#        [-0.35125534, -1.34529973],
#        [ 0.23826411,  0.1301563 ],
#        [-0.54776182,  1.36953936],
#        [-1.43204099,  0.33672014],
#        [-1.13728127,  0.2777019 ],
#        [ 1.02429004,  1.78266705],
#        [ 2.10507569,  2.13677649],
#        [-0.2530021 , -0.46002611],
#        [-0.35125534, -0.81413556],
#        [ 0.14001087, -0.28297139],
#        [-1.03902802,  0.74984783],
#        [ 2.20332893,  0.36622926],
#        [-1.33378775, -0.46002611],
#        [ 2.00682245,  2.16628562],
#        [ 1.51555624,  0.98592079],
#        [-0.2530021 ,  0.24819278],
#        [-0.15474885,  0.83837519],
#        [ 1.90856921, -0.31248051],
#        [-0.05649561,  1.95972177],
#        [-0.44950858, -0.81413556],
#        [ 0.33651735,  0.01211982],
#        [ 1.417303  , -1.46333621],
#        [ 1.417303  ,  2.34334034],
#        [-0.05649561, -0.0173893 ],
#        [-1.13728127,  0.39573838],
#        [-1.13728127,  0.04162894],
#        [-1.13728127, -0.54855347],
#        [ 0.33651735, -0.31248051],
#        [-0.64601506, -0.13542579],
#        [-0.05649561,  2.16628562],
#        [ 0.04175763, -0.28297139],
#        [-0.64601506, -1.07971764],
#        [ 0.43477059,  0.1301563 ],
#        [ 0.82778356,  1.36953936],
#        [-0.15474885, -0.54855347],
#        [ 0.04175763,  0.01211982],
#        [ 1.12254328,  0.51377487],
#        [ 1.90856921, -1.10922676],
#        [ 1.02429004,  1.98923089],
#        [ 0.9260368 , -0.60757171],
#        [-0.44950858, -0.04689842],
#        [-0.05649561,  2.22530386],
#        [-1.72680071,  0.33672014],
#        [ 0.23826411, -0.69609908],
#        [-0.2530021 , -1.43382709],
#        [-1.72680071, -1.0206994 ],
#        [ 0.72953032, -0.75511732],
#        [-1.13728127, -0.81413556],
#        [ 2.00682245,  0.89739343],
#        [ 0.23826411, -0.40100787],
#        [ 0.04175763,  1.22199376],
#        [-0.05649561,  0.2777019 ],
#        [ 1.12254328, -1.25677236],
#        [-0.15474885,  0.1301563 ],
#        [ 0.33651735,  0.04162894],
#        [-0.2530021 , -0.31248051],
#        [ 0.53302383,  1.72364881],
#        [ 0.33651735,  0.48426575],
#        [ 0.04175763,  1.25150288],
#        [ 2.00682245, -1.40431797],
#        [-1.13728127, -1.13873588],
#        [-0.54776182, -1.55186357],
#        [ 0.33651735, -0.54855347],
#        [-0.64601506, -1.55186357],
#        [-0.2530021 ,  0.51377487],
#        [ 1.02429004, -1.05020852],
#        [-1.03902802,  0.54328399],
#        [-0.2530021 ,  0.77935695],
#        [ 0.43477059,  0.07113806],
#        [-1.62854747, -0.07640754],
#        [ 0.33651735,  0.04162894],
#        [-0.44950858, -0.31248051],
#        [ 0.14001087,  1.87119441],
#        [-0.94077478,  0.39573838],
#        [ 0.82778356,  0.51377487],
#        [-1.33378775, -0.37149875],
#        [-0.64601506,  1.39904848],
#        [ 1.22079652,  0.51377487],
#        [-1.72680071,  0.33672014],
#        [-0.54776182,  1.90070353],
#        [-1.72680071,  0.45475663],
#        [-0.2530021 , -1.28628149],
#        [-0.84252154, -0.81413556],
#        [-1.62854747,  0.51377487],
#        [-0.2530021 , -0.34198963],
#        [ 0.72953032, -1.13873588],
#        [ 2.20332893, -0.84364468],
#        [-0.2530021 ,  0.60230223],
#        [-0.2530021 , -0.78462644],
#        [-1.9233072 , -0.78462644],
#        [ 0.43477059,  2.31383122],
#        [ 0.72953032,  0.24819278],
#        [ 0.23826411, -0.31248051],
#        [-1.33378775, -1.40431797],
#        [-0.44950858, -0.57806259],
#        [ 0.43477059, -0.0173893 ],
#        [ 1.71206273,  1.75315793],
#        [ 1.22079652, -0.78462644],
#        [ 1.02429004,  1.4285576 ],
#        [-1.82505395,  0.15966542],
#        [ 0.33651735,  0.04162894],
#        [ 0.23826411,  0.01211982],
#        [-1.03902802,  0.51377487],
#        [-0.15474885,  1.63512145],
#        [-0.2530021 ,  0.1301563 ],
#        [-0.2530021 , -0.37149875],
#        [-0.35125534,  1.31052112],
#        [-0.2530021 ,  0.07113806],
#        [ 2.20332893,  1.10395728],
#        [-1.23553451,  0.48426575],
#        [-1.03902802, -0.48953523],
#        [-1.62854747, -1.61088181],
#        [-0.05649561,  0.10064718],
#        [-0.2530021 , -0.93217204],
#        [ 1.61380949, -0.0173893 ],
#        [ 0.9260368 , -1.19775412],
#        [ 0.04175763, -0.60757171],
#        [-0.2530021 ,  2.25481298],
#        [-0.2530021 ,  0.18917454],
#        [ 0.33651735,  0.24819278],
#        [-0.05649561, -1.10922676],
#        [ 2.20332893, -0.7256082 ],
#        [-0.94077478, -0.34198963],
#        [-1.43204099, -0.13542579],
#        [-1.43204099, -0.22395315],
#        [-0.7442683 , -1.58137269],
#        [-1.23553451, -1.10922676],
#        [ 2.10507569,  0.36622926],
#        [ 2.00682245, -0.96168116],
#        [-1.9233072 ,  0.33672014],
#        [ 0.82778356, -0.34198963],
#        [-1.03902802, -1.58137269],
#        [ 2.00682245, -0.69609908],
#        [ 1.02429004, -1.19775412],
#        [ 1.12254328, -0.16493491],
#        [ 1.22079652, -1.0206994 ],
#        [ 1.51555624,  0.04162894],
#        [ 0.23826411, -0.40100787],
#        [ 1.417303  ,  1.281012  ],
#        [ 2.10507569, -0.84364468],
#        [-0.15474885, -0.22395315],
#        [ 0.43477059,  0.98592079],
#        [-0.05649561, -0.54855347],
#        [ 1.02429004, -1.10922676],
#        [ 2.10507569, -1.22726324],
#        [-0.05649561,  0.24819278],
#        [ 0.23826411, -0.28297139],
#        [ 1.12254328,  0.10064718],
#        [-1.23553451,  0.57279311],
#        [-0.7442683 , -1.64039093],
#        [ 0.23826411,  0.21868366],
#        [-1.33378775,  0.39573838],
#        [ 0.04175763, -0.60757171],
#        [ 0.72953032,  1.78266705],
#        [-1.62854747,  0.04162894],
#        [-0.2530021 , -1.40431797],
#        [-0.2530021 , -1.49284533],
#        [-0.64601506,  0.54328399],
#        [-0.7442683 ,  0.2777019 ],
#        [ 0.9260368 , -0.69609908],
#        [-1.03902802,  0.57279311],
#        [-0.2530021 ,  0.04162894],
#        [-0.7442683 ,  1.34003024],
#        [ 0.14001087,  1.51708496],
#        [-0.84252154,  0.36622926],
#        [ 0.33651735, -0.22395315],
#        [ 1.02429004,  0.57279311],
#        [ 0.04175763, -0.34198963],
#        [-0.54776182, -1.55186357],
#        [ 0.14001087,  0.1301563 ],
#        [-1.13728127,  0.30721102],
#        [ 0.14001087,  1.04493904],
#        [-1.53029423, -0.46002611],
#        [-0.15474885,  1.39904848],
#        [ 2.20332893, -0.84364468],
#        [-0.94077478, -0.46002611],
#        [ 1.31904976,  1.87119441],
#        [ 1.12254328, -1.25677236],
#        [-0.15474885, -0.31248051],
#        [ 1.81031597,  0.98592079],
#        [-1.03902802, -0.37149875],
#        [-1.33378775, -1.13873588],
#        [-0.35125534,  0.04162894],
#        [-0.94077478, -1.13873588],
#        [ 1.22079652, -1.49284533],
#        [-0.44950858, -0.8731538 ],
#        [-0.84252154, -0.69609908],
#        [-1.53029423, -1.55186357],
#        [-0.7442683 ,  1.90070353],
#        [ 0.9260368 ,  1.01542992],
#        [ 0.82778356,  0.24819278],
#        [ 1.02429004,  1.87119441],
#        [ 0.9260368 , -0.63708083],
#        [ 1.12254328,  2.07775825],
#        [-0.54776182,  0.86788431],
#        [ 0.04175763,  0.01211982],
#        [-1.82505395, -1.31579061],
#        [-0.05649561,  0.18917454],
#        [ 0.9260368 , -0.57806259],
#        [ 0.23826411, -0.40100787],
#        [-0.15474885,  1.60561233],
#        [-1.72680071,  0.10064718],
#        [-0.64601506, -0.37149875],
#        [ 0.33651735, -0.75511732],
#        [ 0.43477059, -0.48953523],
#        [-0.94077478, -0.99119028],
#        [ 0.14001087,  0.07113806],
#        [-0.94077478,  0.4252475 ],
#        [ 0.04175763, -0.57806259],
#        [ 0.9260368 , -0.81413556],
#        [-0.05649561,  0.04162894],
#        [ 1.12254328, -1.0206994 ],
#        [ 0.72953032, -1.43382709],
#        [-0.2530021 ,  0.04162894],
#        [-1.33378775, -1.28628149],
#        [-1.13728127, -1.05020852],
#        [ 0.53302383,  1.84168529],
#        [ 0.14001087,  0.18917454],
#        [-0.54776182,  0.45475663]])

# %%
X_train_scaled= pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled= pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    37.6          70589.3
# std     10.2          33948.5
# min     18.0          15000.0
# 25%     30.0          44000.0
# 50%     37.0          71000.0
# 75%     45.0          88000.0
# max     60.0         150000.0

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    -0.0              0.0
# std      1.0              1.0
# min     -1.9             -1.6
# 25%     -0.7             -0.8
# 50%     -0.1              0.0
# 75%      0.7              0.5
# max      2.2              2.3

# %% [markdown]
# ## Effect of Scaling

# %%
# %matplotlib inline

# %%
fig, (ax1, ax2)= plt.subplots(ncols=2 , figsize =(10,4))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# ## Comparison of Distributions

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Age Distribution Before Scaling')
sns.kdeplot(X_train['Age'], ax=ax1)

# after scaling
ax2.set_title('Age Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Age'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Salary Distribution Before Scaling')
sns.kdeplot(X_train['EstimatedSalary'], ax=ax1)

# after scaling
ax2.set_title('Salary Distribution Standard Scaling')
sns.kdeplot(X_train_scaled['EstimatedSalary'], ax=ax2)
plt.show()

# %% [markdown]
# ## Why scaling is important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr_scaled = LogisticRegression()

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.85
# Scaled 0.85

# %%
whyyy is this same???????
